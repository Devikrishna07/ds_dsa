# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None

# %%
n1=Node("krishna")
n2=Node("athulya")
n3=Node("devikrishna")

# %%
n1.next=n2
n2.prev=n1
n2.next=n3
n3.prev=n1

# %%
class Nodes:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None

# %%
n1=Node(500)
n2=Node(600)
n3=Node(700)
n4=Node(800)

# %%
n1.next=n2
n2.prev=n1
n2.next=n3
n3.prev=n2
n3.next=n4
n4.prev=n3

# %%
cur=n1
values=[]
while cur:
    values.append(cur.data)
    cur=cur.next
values.sort()
print(values[-2])
# Out:
# 700

# %%
def missing_num(num,n):
    total=n*(n+1)//2
    sum_num=sum(num)
    return total-sum_num
n= int(input("Enter n")) 
num=list(map(int,input(f"Enter {n-1} number").split(',')))
missing = missing_num(num,n)
print("Missing num is:",missing)
# Out:
# Enter n 5
# Enter 4 number 1,2,3,5
# Missing num is: 4

# %%
# 30,40,50,60 enter the node 35 betweeen 30 and 40

# %%
class Nodees:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None

# %%
n1=Node(30)
n2=Node(40)
n3=Node(50)
n4=Node(60)
n5=Node(35)

# %%
n1.next=n5
n5.next=n2
n2.prev=n5
n2.next=n3
n3.next=n4

# %%
cur=n1
values=[]
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 30
# 35
# 40
# 50
# 60

# %%
head=n1
x=int(input("enter the number "))
new_node=Node(x)
cur=head
if x < head.data:
    new_node.next=head
    head.prev=new_node
    head=new_node
else:
    while cur.next and cur.next.data < x:
        cur = cur.next
    new_node.next = cur.next
    new_node.prev = cur
    if cur.next:
        cur.next.prev = new_node
    cur.next = new_node
cur=head
values=[]
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# enter the number  34
# 30
# 34
# 35
# 40
# 50
# 60
