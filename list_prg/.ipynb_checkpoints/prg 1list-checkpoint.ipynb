# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv("tip.csv")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#list operations

# %%
l1=list()

# %%
type(l1)
# Out:
# list

# %%
l1.append(10)

# %%
l1
# Out:
# [10]

# %%
l1.append(20)

# %%
l1.append(30)

# %%
l1
# Out:
# [10, 20, 30]

# %%
l1.append(50)

# %%
l1
# Out:
# [10, 20, 30, 50]

# %%
l1.sort()

# %%
l1
# Out:
# [10, 20, 30, 50]

# %%
num=(2,5,3,1,6,4,7,15,10)

# %%
nums=sorted(num)

# %%
names=['joe','mahek','steve','rahul','niya']

# %%
names
# Out:
# ['joe', 'mahek', 'steve', 'rahul', 'niya']

# %%
snames=sorted(names)

# %%
snames
# Out:
# ['joe', 'mahek', 'niya', 'rahul', 'steve']

# %%
#sort names based on len

# %%
lnames=sorted(names,key=len)

# %%
lnames
# Out:
# ['joe', 'niya', 'mahek', 'steve', 'rahul']

# %%
lnames=sorted(names,key=len,reverse= True)

# %%
lnames
# Out:
# ['mahek', 'steve', 'rahul', 'niya', 'joe']

# %%
lnum=[ i for i in range(1,10)]

# %%
lnum
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
lnum=[ 4** i for i in range(1,10)]

# %%
lnum
# Out:
# [4, 16, 64, 256, 1024, 4096, 16384, 65536, 262144]

# %%
#0,2,4,6,8,16,.....

# %%
lnum=[0 if i==0 else 2**i for i in range(0,10)]

# %%
lnum
# Out:
# [0, 2, 4, 8, 16, 32, 64, 128, 256, 512]

# %%
n=[2** i for i in range(0,9)]
n[0]=0

# %%
n
# Out:
# [0, 2, 4, 8, 16, 32, 64, 128, 256]

# %%
#1,3,5,7

# %%
odd=[i for i in range(1,10) if i%2==1]

# %%
odd
# Out:
# [1, 3, 5, 7, 9]

# %%
## remove duplicate

# %%
m=[2,3,4,2,6,7]

# %%
rm=[]

# %%
for i in m:
    if i not in rm:
        rm.append(i)

# %%
rm
# Out:
# [2, 3, 4, 6, 7]

# %%
#reverse

# %%
lm=[2,3,4,1,5,9]

# %%
lm[::-1]
# Out:
# [9, 5, 1, 4, 3, 2]

# %%
lm
# Out:
# [2, 3, 4, 1, 5, 9]

# %%
nm=[2, 3, 4, 1, 5, 9]
#target=5 o/p=[2,3]  target=14 o/p=[5,9]

# %%
d={'a':100,'b':200,'c':300}

# %%
d.get('a')
# Out:
# 100

# %%
d.get("d",0)
# Out:
# 0

# %%
d.popitem() #remove last item
# Out:
# ('b', 200)

# %%
d.pop('a')
# Out:
# {}

# %%
emp={'id':1000,'name':'joe','salary':'1500000'}

# %%
emp.setdefault('id',1200)
# Out:
# 1000

# %%
emp.setdefault('place','goa')
# Out:
# 'goa'

# %%
emp
# Out:
# {'id': 1000, 'name': 'joe', 'salary': '1500000', 'place': 'goa'}

# %%
dict_items([('id', 1000), ('name', 'joe'), ('salary','1500000'), ('place','goa')])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 dict_items([('id', 1000), ('name', 'joe'), ('salary','1500000'), ('place','goa')])
#
# NameError: name 'dict_items' is not defined

# %%
t2=([1,2,3],[2,5,6])

# %%
t2
# Out:
# ([1, 2, 3], [2, 5, 6])

# %%
t2[1][2]=3

# %%
t2
# Out:
# ([1, 2, 3], [2, 5, 3])

# %%
t2[1]=222
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 t2[1]=222
#
# TypeError: 'tuple' object does not support item assignment

# %%
# set mutable --{}

# %%
s1={1,3,4,5,3}

# %%
s1
# Out:
# {1, 3, 4, 5}

# %%
l=[2,3,2,4,4,5]

# %%
ls=set(l)

# %%
ls
# Out:
# {2, 3, 4, 5}

# %%
s1={1,3,4,5,3,3773,66,4444}# does'nt support insertion order->set

# %%
s1
# Out:
# {1, 3, 4, 5, 66, 3773, 4444}
