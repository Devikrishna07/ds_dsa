# %%
class Stack:
    def __init__(self):
        self.data=[]
    def push(self,item):
        self.data.append(item)
    def display(self):
        for i in range(-1,-6,-1):
            print(self.data[i],sep='') #or  for i in range(-1,-len(self.data),-1):
                                    #      print(self.data[i],sep='')

# %%
s=Stack()
s.push(10)
s.push(20)
s.push(30)
s.push(40)
s.push(50)

# %%
print(s.data)
# Out:
# [10, 20, 30, 40, 50]

# %%
s.display()
# Out:
# 50
# 40
# 30
# 20
# 10

# %%
class Stack:
    def __init__(self):
        self.data=[]
    def push(self,item):
        self.data.append(item)
    def display(self):
        for i in range(-1,-len(self.data),-1):
            print(self.data[i],sep='')
    def pop(self):
        if self.is_empty() !=True:
            return self.data.pop()
        else:
            print("Stack is empty")
    def is_empty(self):
        if len(self.data)==0:
            return True
    def peek(self):
        if self.is_empty()!=True:
            return self.data[-1]
        else:
            print("Stack is empty")

# %%
s=Stack()
s.push(10)
s.push(20)
s.push(30)
s.push(40)
s.push(50)

# %%
s.display()
# Out:
# 50
# 40
# 30
# 20

# %%
s.pop()
# Out:
# 50

# %%
s.display()
# Out:
# 40
# 30
# 20

# %%
s.pop()
# Out:
# 40

# %%
s.display()
# Out:
# 30
# 20

# %%
s.pop()
# Out:
# 30

# %%
s.display()
# Out:
# 20

# %%
s.pop()
# Out:
# 20

# %%
s.display()

# %%
s.pop()
# Out:
# 10

# %%
s.display()

# %%
s.pop()
# Out:
# Stack is empty

# %%
s.display()

# %%
s.pop()
# Out:
# Stack is empty

# %%
s.peek()
# Out:
# Stack is empty
